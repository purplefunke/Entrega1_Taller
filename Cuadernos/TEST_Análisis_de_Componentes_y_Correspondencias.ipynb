# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
dataset = pd.read_csv('../Datos/Base.csv')
X = dataset.drop(columns=['NObeyesdad'])
y = dataset['NObeyesdad']

# %%
print(dataset)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
dataset.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
dataset.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
dataset.describe()
numeric= dataset.select_dtypes(include=["number"])
numeric_df=numeric.copy()
numeric.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
correlation_matrix = numeric.corr()
print(correlation_matrix)
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016291 -0.043944 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038121  0.243672  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.216125  0.107469  0.200575 -0.051436
# FCVC    0.016291 -0.038121  0.216125  1.000000  0.042216  0.068461  0.019939
# NCP    -0.043944  0.243672  0.107469  0.042216  1.000000  0.057088  0.129504
# CH2O   -0.045304  0.213376  0.200575  0.068461  0.057088  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019939  0.129504  0.167236  1.000000
# TUE    -0.296931  0.051912 -0.071561 -0.101135  0.036326  0.011965  0.058562
#
#              TUE
# Age    -0.296931
# Height  0.051912
# Weight -0.071561
# FCVC   -0.101135
# NCP     0.036326
# CH2O    0.011965
# FAF     0.058562
# TUE     1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
#instanciamos el objeto PCA
# modelo pide borrar n_iter
# aunque aca no corre abajo lo ejecuta porque???
# no me deja incluit los otros. 
pca = PCA(
    n_components=8,    


     copy=True,


     random_state=42
 )

# %%
## Standarizamos los datos

scaler = StandardScaler()
scaler.fit(numeric)
numeric = scaler.transform(numeric)


pca = PCA()
pca.fit(numeric)
# Out:
# PCA()

# %%
explained_cumulative = pca.explained_variance_ratio_.cumsum()
n_components = (explained_cumulative >= 0.90).argmax() + 1
print("Número de componentes para explicar al menos el 90% de la varianza:", n_components)
# Out:
# Número de componentes para explicar al menos el 90% de la varianza: 7

# %%
### Grafiquemos en los dos primeros componentes principales
### las observaciones de nuestro dataset

pca = PCA(n_components=8)
X_pca = pca.fit_transform(numeric)
## Sacamos los dos primeros componentes principales
X_pca_2PC = X_pca[:, :2]

X_pca_2PC = pd.DataFrame(X_pca_2PC, columns=["Componente 1", "Componente 2"])
X_pca_2PC["y"] = y

plt.figure(figsize=(10, 8))
sns.scatterplot(data=X_pca_2PC, x="Componente 1", y="Componente 2", hue="y")

plt.title("PCA con 2 componentes principales")
plt.show()

# %%
## Grafiquemos las coordenadas de las variables en el primer plano factorial

loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
loadings = loadings[:, :2]
loading_matrix = pd.DataFrame(loadings, columns=["Componente 1", "Componente 2"], index=numeric_df.columns)

plt.figure(figsize=(10, 8))

plt.scatter(loading_matrix["Componente 1"], loading_matrix["Componente 2"], color='red')
plt.xlabel("Componente 1")
plt.ylabel("Componente 2")

for i in loading_matrix.index:
    plt.text(loading_matrix.loc[i, "Componente 1"], loading_matrix.loc[i, "Componente 2"], i)

plt.title("Primer plano factorial")
plt.grid()
plt.show()

# %%
explained_cumulative = pca.explained_variance_ratio_.cumsum()
print(explained_cumulative)
# Out:
# [0.22648604 0.41306498 0.53951884 0.65838289 0.77596136 0.87268349
#  0.95462974 1.        ]

# %%
DF_PCA=pca.transform(numeric)
DF_PCA



DF_PCA_PANDA= pd.DataFrame(DF_PCA)

DF_PCA_PANDA.describe()
# Out:
#                   0            1             2            3             4  \
# count  2.111000e+03  2111.000000  2.111000e+03  2111.000000  2.111000e+03
# mean  -5.385449e-17     0.000000 -4.375678e-17     0.000000  6.731812e-18
# std    1.346383e+00     1.222022  1.006037e+00     0.975378  9.700895e-01
# min   -3.421757e+00    -3.705529 -2.259344e+00    -2.460691 -2.845714e+00
# 25%   -9.638963e-01    -0.869202 -8.258128e-01    -0.708961 -6.821173e-01
# 50%   -2.236188e-02     0.043312 -1.602104e-02    -0.028922 -1.401010e-02
# 75%    9.331602e-01     0.876955  6.797202e-01     0.638074  4.781011e-01
# max    3.813435e+00     4.213769  2.959325e+00     3.241798  2.897199e+00
#
#                   5             6             7
# count  2.111000e+03  2.111000e+03  2.111000e+03
# mean  -3.365906e-17 -8.414765e-19 -4.039087e-17
# std    8.798544e-01  8.098646e-01  6.026061e-01
# min   -2.935863e+00 -2.111375e+00 -1.670251e+00
# 25%   -5.844020e-01 -5.462526e-01 -4.206035e-01
# 50%   -1.252422e-02 -7.542060e-02 -2.704193e-02
# 75%    5.611074e-01  4.593855e-01  4.286743e-01
# max    3.003668e+00  4.723630e+00  2.126773e+00

# %%
DF_PCA_PANDA.corr()
# Out:
#               0             1             2             3             4  \
# 0  1.000000e+00  7.368218e-16  5.450857e-16  5.682292e-16  5.051786e-17
# 1  7.368218e-16  1.000000e+00 -2.773382e-17 -1.107362e-16 -4.835752e-17
# 2  5.450857e-16 -2.773382e-17  1.000000e+00 -7.587473e-17  2.483282e-16
# 3  5.682292e-16 -1.107362e-16 -7.587473e-17  1.000000e+00 -7.212450e-16
# 4  5.051786e-17 -4.835752e-17  2.483282e-16 -7.212450e-16  1.000000e+00
# 5 -1.361378e-16  1.065115e-16 -3.744335e-16  2.615867e-16  7.024874e-16
# 6 -8.540317e-17  4.912580e-16  1.633342e-16  1.247540e-16 -5.061424e-17
# 7  5.860057e-16  3.503654e-16  8.058649e-16  6.060071e-16 -1.714883e-16
#
#               5             6             7
# 0 -1.361378e-16 -8.540317e-17  5.860057e-16
# 1  1.065115e-16  4.912580e-16  3.503654e-16
# 2 -3.744335e-16  1.633342e-16  8.058649e-16
# 3  2.615867e-16  1.247540e-16  6.060071e-16
# 4  7.024874e-16 -5.061424e-17 -1.714883e-16
# 5  1.000000e+00  1.162218e-16 -2.042344e-16
# 6  1.162218e-16  1.000000e+00 -2.034768e-16
# 7 -2.042344e-16 -2.034768e-16  1.000000e+00

# %%
### Veamos la varianza explicada por cada componente

explained_variance = pca.explained_variance_ratio_

explained_variance
# Out:
# array([0.22648604, 0.18657893, 0.12645386, 0.11886405, 0.11757848,
#        0.09672213, 0.08194625, 0.04537026])

# %%
## Grafiquemos cada variable en las diferentes componentes

# %%
DF_PCA_PANDA.describe()
# Out:
#                   0            1             2            3             4  \
# count  2.111000e+03  2111.000000  2.111000e+03  2111.000000  2.111000e+03
# mean  -5.385449e-17     0.000000 -4.375678e-17     0.000000  6.731812e-18
# std    1.346383e+00     1.222022  1.006037e+00     0.975378  9.700895e-01
# min   -3.421757e+00    -3.705529 -2.259344e+00    -2.460691 -2.845714e+00
# 25%   -9.638963e-01    -0.869202 -8.258128e-01    -0.708961 -6.821173e-01
# 50%   -2.236188e-02     0.043312 -1.602104e-02    -0.028922 -1.401010e-02
# 75%    9.331602e-01     0.876955  6.797202e-01     0.638074  4.781011e-01
# max    3.813435e+00     4.213769  2.959325e+00     3.241798  2.897199e+00
#
#                   5             6             7
# count  2.111000e+03  2.111000e+03  2.111000e+03
# mean  -3.365906e-17 -8.414765e-19 -4.039087e-17
# std    8.798544e-01  8.098646e-01  6.026061e-01
# min   -2.935863e+00 -2.111375e+00 -1.670251e+00
# 25%   -5.844020e-01 -5.462526e-01 -4.206035e-01
# 50%   -1.252422e-02 -7.542060e-02 -2.704193e-02
# 75%    5.611074e-01  4.593855e-01  4.286743e-01
# max    3.003668e+00  4.723630e+00  2.126773e+00

# %%
# Assuming DF_PCA is a NumPy array
DF_PCA = pd.DataFrame(DF_PCA, columns=['Componente 1', 'Componente 2', 'Componente 3', 'Componente 4', 'Componente 5', 'Componente 6', 'Componente 7', 'Componente 8'])

# Now you can access columns attribute
print(DF_PCA)
# Out:
#       Componente 1  Componente 2  Componente 3  Componente 4  Componente 5  \
# 0         1.333029     -0.689743      0.305922     -0.733236     -0.103475
# 1         0.087728     -0.727529     -2.067507      2.956012     -0.384996
# 2        -0.828980     -1.305978      0.898384      0.475035     -0.058444
# 3        -1.305491      0.572544     -0.366069      1.250744     -0.792708
# 4         0.690310      0.842111      0.478263     -0.111392      1.853180
# ...            ...           ...           ...           ...           ...
# 2106     -1.308977      0.050855     -0.890030     -0.685840     -0.644063
# 2107     -1.637764      0.536557     -0.793394     -0.596949     -0.399693
# 2108     -1.720038      0.508361     -0.780803     -0.560407     -0.346816
# 2109     -2.029482      0.788680     -1.045579     -0.377248      0.362826
# 2110     -1.994673      0.659733     -1.093585     -0.598345      0.409047
#
#       Componente 6  Componente 7  Componente 8
# 0        -1.171206     -0.145143      0.053731
# 1        -0.994520      0.569710     -1.014445
# 2         0.422251      0.237965      0.272044
# 3         0.680997     -0.070731      0.577275
# 4         0.656402     -1.708059      0.731487
# ...            ...           ...           ...
# 2106      0.963333      0.017308     -1.109276
# 2107      0.598760     -0.334827     -0.743850
# 2108      0.598739     -0.207190     -0.725193
# 2109     -0.433839      0.006236     -0.582925
# 2110     -0.482599      0.019941     -0.558963
#
# [2111 rows x 8 columns]

# %%
y
# Out:
# 0             Normal_Weight
# 1             Normal_Weight
# 2             Normal_Weight
# 3        Overweight_Level_I
# 4       Overweight_Level_II
#                ...
# 2106       Obesity_Type_III
# 2107       Obesity_Type_III
# 2108       Obesity_Type_III
# 2109       Obesity_Type_III
# 2110       Obesity_Type_III
# Name: NObeyesdad, Length: 2111, dtype: object

# %%
sns.scatterplot(x=DF_PCA_PANDA[0], y=DF_PCA_PANDA[7],data=DF_PCA_PANDA)
# Out:
# <Axes: xlabel='0', ylabel='7'>

# %%
sns.scatterplot(x=DF_PCA_PANDA[1], y=DF_PCA_PANDA[7],data=DF_PCA_PANDA)
# Out:
# <Axes: xlabel='1', ylabel='7'>

# %%
sns.scatterplot(x=DF_PCA_PANDA[2], y=DF_PCA_PANDA[3],data=DF_PCA_PANDA)
# Out:
# <Axes: xlabel='2', ylabel='3'>

# %%
sns.scatterplot(x=DF_PCA_PANDA[4], y=DF_PCA_PANDA[6],data=DF_PCA_PANDA)
# Out:
# <Axes: xlabel='4', ylabel='6'>

# %%
sns.scatterplot(x=DF_PCA_PANDA[6], y=DF_PCA_PANDA[7],data=DF_PCA_PANDA)
# Out:
# <Axes: xlabel='6', ylabel='7'>

# %%
sns.scatterplot(x=DF_PCA_PANDA[0], y=DF_PCA_PANDA[7],data=DF_PCA_PANDA)
# Out:
# <Axes: xlabel='0', ylabel='7'>

# %%
from sklearn.decomposition import PCA

# Assuming pca is your PCA object
pca = PCA(n_components=8)
pca.fit(DF_PCA_PANDA)

# Calculate cumulative percentage of variance explained
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

print(cumulative_variance_ratio)
# Out:
# [0.22648604 0.41306498 0.53951884 0.65838289 0.77596136 0.87268349
#  0.95462974 1.        ]

# %%
from sklearn.decomposition import PCA

# Assuming pca is your PCA object
pca = PCA(n_components=8)
pca.fit(DF_PCA_PANDA)

# Extract eigenvalues (variances)
eigenvalues = pca.explained_variance_

print(eigenvalues)
# Out:
# [1.81274705 1.49333888 1.01211035 0.95136305 0.9410736  0.77414375
#  0.6558807  0.3631341 ]

# %%
# Assuming pca is your PCA object
pca = PCA(n_components=8)
pca.fit(DF_PCA_PANDA)

# Calculate total inertia (total variance)
total_inertia = sum(pca.explained_variance_)

print(total_inertia)
# Out:
# 8.00379146919431

# %%
# Assuming pca is your PCA object
pca = PCA(n_components=8)
pca.fit(DF_PCA_PANDA)

# Access the loadings (components)
loadings = pca.components_

print(loadings)
# Out:
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  1.29296521e-15 -4.74983083e-16
#   -3.99721224e-16 -1.49056869e-16  2.40771938e-16  3.03644801e-16]
#  [-0.00000000e+00 -7.97022551e-16  1.00000000e+00  1.59557984e-14
#    8.18571688e-15 -1.75890117e-15  1.60224929e-15  1.39957594e-16]
#  [-0.00000000e+00  6.88097476e-16 -1.58892325e-14  1.00000000e+00
#   -9.18288345e-14  8.33443578e-16  3.07611104e-15  1.00616345e-15]
#  [-0.00000000e+00  3.62163978e-16 -7.73997163e-15  9.17520396e-14
#    1.00000000e+00  5.41330198e-15 -6.13864389e-16 -2.11957944e-16]
#  [-0.00000000e+00  9.99083130e-17  9.71805587e-16 -6.37414891e-16
#   -5.37635845e-15  1.00000000e+00 -2.22281072e-15 -3.45277730e-18]
#  [ 0.00000000e+00 -2.99425234e-16 -1.90966229e-15 -2.71703446e-15
#    5.27152062e-16  1.98033555e-15  1.00000000e+00 -3.69074943e-16]
#  [-0.00000000e+00 -7.96134741e-17 -4.03387018e-16 -9.15220113e-16
#    2.23989518e-16  1.25305153e-16  3.54697186e-16  1.00000000e+00]]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Assuming pca is your PCA object
pca = PCA(n_components=8)
pca.fit(DF_PCA_PANDA)

# Access the principal axes (components)
components = pca.components_

fig, ax = plt.subplots()
ax.axhline(-1.5,1.5, color='gray', lw=0.5)
ax.axvline(-1.5,1.5, color='gray', lw=0.5)

for idx, (x, y) in enumerate(zip(components[:, 0], components[:, 7])):
    ax.arrow(0, 0, x, y, head_width=0.05, head_length=0.1)
    ax.text(x, y, f"Feature {idx+1}")

plt.xlabel('Component 0')
plt.ylabel('Component 7')
plt.title('Correlation between Original Features and Principal Components')
plt.show()

# %% [markdown]
# Analisis de Correspondencias

# %%
dataset.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
datasetC=dataset.drop(columns=['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE', 'NObeyesdad'], axis=1)
datasetC.head()
# Out:
#    Gender family_history_with_overweight FAVC       CAEC SMOKE  SCC  \
# 0  Female                            yes   no  Sometimes    no   no
# 1  Female                            yes   no  Sometimes   yes  yes
# 2    Male                            yes   no  Sometimes    no   no
# 3    Male                             no   no  Sometimes    no   no
# 4    Male                             no   no  Sometimes    no   no
#
#          CALC                 MTRANS
# 0          no  Public_Transportation
# 1   Sometimes  Public_Transportation
# 2  Frequently  Public_Transportation
# 3  Frequently                Walking
# 4   Sometimes  Public_Transportation

# %%
import prince

## Instanciamos el objeto
mca = prince.MCA(
    n_components=8,
    n_iter=3,
    copy=True,
    check_input=True,
    engine='sklearn',
    random_state=42
)

## Entrenamos el objeto
mca = mca.fit(datasetC)

# %%
mca.eigenvalues_summary
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              0.225        12.02%                     12.02%
# 1              0.165         8.77%                     20.80%
# 2              0.145         7.74%                     28.54%
# 3              0.140         7.44%                     35.98%
# 4              0.135         7.18%                     43.16%
# 5              0.130         6.91%                     50.08%
# 6              0.126         6.70%                     56.78%
# 7              0.120         6.41%                     63.19%

# %%
mca.row_coordinates(datasetC)
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.384984  0.010481  0.594911 -0.150619 -0.233556 -0.203745 -0.094855
# 1     1.148210  0.453200 -0.795005 -0.943597  0.659616 -0.417423  0.964193
# 2     0.424655  0.894312 -0.383943 -0.512687  0.312116 -0.335320 -0.468413
# 3     1.325299  1.489080 -0.163120  0.589741  0.681589 -0.540815 -0.557460
# 4     0.603687 -0.036039 -0.140537  0.247412 -0.252461  0.025559 -0.027187
# ...        ...       ...       ...       ...       ...       ...       ...
# 2106 -0.202658 -0.366104  0.006706 -0.037931  0.140588 -0.193014  0.184358
# 2107 -0.202658 -0.366104  0.006706 -0.037931  0.140588 -0.193014  0.184358
# 2108 -0.202658 -0.366104  0.006706 -0.037931  0.140588 -0.193014  0.184358
# 2109 -0.202658 -0.366104  0.006706 -0.037931  0.140588 -0.193014  0.184358
# 2110 -0.202658 -0.366104  0.006706 -0.037931  0.140588 -0.193014  0.184358
#
#              7
# 0     0.148705
# 1     1.064381
# 2     0.389918
# 3     0.053802
# 4     0.185950
# ...        ...
# 2106 -0.041264
# 2107 -0.041264
# 2108 -0.041264
# 2109 -0.041264
# 2110 -0.041264
#
# [2111 rows x 8 columns]

# %%
DF_3d=mca.column_coordinates(datasetC)
DF_3d
# Out:
#                                            0         1          2          3  \
# Gender_Female                       0.259064 -0.526517   0.230418  -0.290044
# Gender_Male                        -0.252999  0.514192  -0.225024   0.283255
# family_history_with_overweight_no   1.373411 -0.443149  -0.448024   0.226227
# family_history_with_overweight_yes -0.306352  0.098848   0.099936  -0.050462
# FAVC_no                             1.675089  0.505892   0.490233   0.002542
# FAVC_yes                           -0.219934 -0.066422  -0.064366  -0.000334
# CAEC_Always                         1.326330  2.155621  -1.215081  -0.110363
# CAEC_Frequently                     1.576583 -0.300245   0.701875  -0.540023
# CAEC_Sometimes                     -0.294259  0.003863   0.042408   0.000538
# CAEC_no                             1.324286 -0.949166  -3.535397   2.658525
# SMOKE_no                           -0.015282 -0.042484   0.048722   0.042235
# SMOKE_yes                           0.717897  1.995804  -2.288840  -1.984088
# SCC_no                             -0.113816 -0.002181   0.030045   0.031083
# SCC_yes                             2.388954  0.045768  -0.630641  -0.652422
# CALC_Always                         3.070644  7.284037  11.052103  23.821897
# CALC_Frequently                     0.863068  2.194519  -1.627322  -1.837403
# CALC_Sometimes                     -0.136682 -0.282370  -0.337450   0.157773
# CALC_no                             0.200322  0.367293   0.900826  -0.181915
# MTRANS_Automobile                  -0.488612  0.938931  -0.045140  -0.344556
# MTRANS_Bike                         1.191193  3.125887   0.069987   2.448370
# MTRANS_Motorbike                    2.124477  1.551882  -0.031464  -1.990406
# MTRANS_Public_Transportation        0.057509 -0.370705  -0.029274  -0.004163
# MTRANS_Walking                      1.798640  2.101253   1.191765   3.014205
#
#                                             4         5         6         7
# Gender_Female                        0.205621 -0.347865  0.061314 -0.108084
# Gender_Male                         -0.200807  0.339722 -0.059879  0.105554
# family_history_with_overweight_no   -0.189740  0.249630 -0.301208 -0.114264
# family_history_with_overweight_yes   0.042323 -0.055682  0.067187  0.025488
# FAVC_no                             -0.455311 -0.321156 -0.097582  0.491753
# FAVC_yes                             0.059781  0.042167  0.012812 -0.064566
# CAEC_Always                         -0.478344 -2.140656  1.555903 -3.916531
# CAEC_Frequently                      0.523349  0.741121 -0.184837  0.531005
# CAEC_Sometimes                      -0.027296 -0.076109  0.042164  0.034953
# CAEC_no                             -1.041593  1.341887 -2.199046  0.340810
# SMOKE_no                            -0.051129 -0.008155 -0.046701 -0.060127
# SMOKE_yes                            2.401906  0.383102  2.193873  2.824585
# SCC_no                               0.018855  0.030665 -0.003710  0.017026
# SCC_yes                             -0.395761 -0.643653  0.077873 -0.357367
# CALC_Always                         22.864644  3.495169  6.047312  4.942627
# CALC_Frequently                      1.543398 -0.812131 -1.362536  0.418413
# CALC_Sometimes                       0.118450 -0.077969  0.257262 -0.007566
# CALC_no                             -0.464555  0.254443 -0.424246 -0.036983
# MTRANS_Automobile                   -0.133943  0.175776 -0.751698 -0.104409
# MTRANS_Bike                        -10.084701 -4.706932  6.659448  7.864850
# MTRANS_Motorbike                    -1.563343  9.631323  6.688747 -3.834584
# MTRANS_Public_Transportation         0.046015 -0.063008  0.132547  0.048424
# MTRANS_Walking                       1.362467 -0.960227  0.248386 -0.744083

# %%
mca.plot(
    datasetC,
    x_component=0,
y_component=1,
show_row_markers=False,

)
# Out:
# alt.LayerChart(...)

# %%
mca.column_cosine_similarities(datasetC)
# Out:
#                                            0         1         2  \
# Gender_Female                       0.065543  0.270731  0.051849
# Gender_Male                         0.065543  0.270731  0.051849
# family_history_with_overweight_no   0.420747  0.043805  0.044774
# family_history_with_overweight_yes  0.420747  0.043805  0.044774
# FAVC_no                             0.368409  0.033602  0.031554
# FAVC_yes                            0.368409  0.033602  0.031554
# CAEC_Always                         0.045304  0.119667  0.038023
# CAEC_Frequently                     0.321840  0.011672  0.063786
# CAEC_Sometimes                      0.441701  0.000076  0.009174
# CAEC_no                             0.043418  0.022304  0.309442
# SMOKE_no                            0.010971  0.084791  0.111517
# SMOKE_yes                           0.010971  0.084791  0.111517
# SCC_no                              0.271902  0.000100  0.018948
# SCC_yes                             0.271902  0.000100  0.018948
# CALC_Always                         0.004469  0.025146  0.057891
# CALC_Frequently                     0.025547  0.165171  0.090824
# CALC_Sometimes                      0.036864  0.157332  0.224698
# CALC_no                             0.017420  0.058562  0.352270
# MTRANS_Automobile                   0.065964  0.243584  0.000563
# MTRANS_Bike                         0.004721  0.032509  0.000016
# MTRANS_Motorbike                    0.023642  0.012615  0.000005
# MTRANS_Public_Transportation        0.009841  0.408902  0.002550
# MTRANS_Walking                      0.088159  0.120319  0.038704
#
#                                                3         4         5  \
# Gender_Female                       8.215657e-02  0.041290  0.118177
# Gender_Male                         8.215657e-02  0.041290  0.118177
# family_history_with_overweight_no   1.141587e-02  0.008030  0.013900
# family_history_with_overweight_yes  1.141587e-02  0.008030  0.013900
# FAVC_no                             8.486932e-07  0.027219  0.013542
# FAVC_yes                            8.486932e-07  0.027219  0.013542
# CAEC_Always                         3.136738e-04  0.005893  0.118011
# CAEC_Frequently                     3.775991e-02  0.035464  0.071119
# CAEC_Sometimes                      1.478197e-06  0.003801  0.029549
# CAEC_no                             1.749784e-01  0.026860  0.044579
# SMOKE_no                            8.379809e-02  0.122807  0.003124
# SMOKE_yes                           8.379809e-02  0.122807  0.003124
# SCC_no                              2.027934e-02  0.007462  0.019738
# SCC_yes                             2.027934e-02  0.007462  0.019738
# CALC_Always                         2.689492e-01  0.247769  0.005790
# CALC_Frequently                     1.157880e-01  0.081698  0.022621
# CALC_Sometimes                      4.911860e-02  0.027685  0.011996
# CALC_no                             1.436586e-02  0.093684  0.028104
# MTRANS_Automobile                   3.280192e-02  0.004957  0.008537
# MTRANS_Bike                         1.994374e-02  0.338359  0.073710
# MTRANS_Motorbike                    2.075185e-02  0.012802  0.485898
# MTRANS_Public_Transportation        5.156992e-05  0.006300  0.011813
# MTRANS_Walking                      2.475835e-01  0.050586  0.025126
#
#                                            6         7
# Gender_Female                       0.003671  0.011409
# Gender_Male                         0.003671  0.011409
# family_history_with_overweight_no   0.020237  0.002912
# family_history_with_overweight_yes  0.020237  0.002912
# FAVC_no                             0.001250  0.031750
# FAVC_yes                            0.001250  0.031750
# CAEC_Always                         0.062344  0.395033
# CAEC_Frequently                     0.004424  0.036509
# CAEC_Sometimes                      0.009069  0.006232
# CAEC_no                             0.119721  0.002876
# SMOKE_no                            0.102455  0.169833
# SMOKE_yes                           0.102455  0.169833
# SCC_no                              0.000289  0.006084
# SCC_yes                             0.000289  0.006084
# CALC_Always                         0.017332  0.011578
# CALC_Frequently                     0.063672  0.006004
# CALC_Sometimes                      0.130596  0.000113
# CALC_no                             0.078132  0.000594
# MTRANS_Automobile                   0.156123  0.003012
# MTRANS_Bike                         0.147546  0.205794
# MTRANS_Motorbike                    0.234349  0.077021
# MTRANS_Public_Transportation        0.052276  0.006977
# MTRANS_Walking                      0.001681  0.015088

# %%
### Pintemos en 3d

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_zlim(-1,1)


ax.scatter(DF_3d[0], DF_3d[1], DF_3d[2])

for i in range(len(DF_3d)):
    ax.text(DF_3d.iloc[i,0],DF_3d.iloc[i,1],DF_3d.iloc[i,2],DF_3d.index[i])

plt.show()
